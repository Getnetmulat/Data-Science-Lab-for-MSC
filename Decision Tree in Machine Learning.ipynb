# %% [markdown]
# # Loading Python Libraries

# %%
pip install sqlalchemy
# Out:
# ...
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy as sp
import sqlalchemy

# %%
df = pd.read_csv("C:/Users/getne/Desktop/MSC/Data Science/User_Data.csv")

# %% [markdown]
# # Exploring data frames

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# User ID             int64
# Gender             object
# Age                 int64
# EstimatedSalary     int64
# Purchased           int64
# dtype: object

# %%
df.shape
# Out:
# (400, 5)

# %%
df.size
# Out:
# 2000

# %%
df.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
df['EstimatedSalary'][:5]
# Out:
# 0    19000
# 1    20000
# 2    43000
# 3    57000
# 4    76000
# Name: EstimatedSalary, dtype: int64

# %%
df.EstimatedSalary.describe()
# Out:
# count       400.000000
# mean      69742.500000
# std       34096.960282
# min       15000.000000
# 25%       43000.000000
# 50%       70000.000000
# 75%       88000.000000
# max      150000.000000
# Name: EstimatedSalary, dtype: float64

# %%
df.EstimatedSalary.count()
# Out:
# 400

# %%
df.count()
# Out:
# User ID            400
# Gender             400
# Age                400
# EstimatedSalary    400
# Purchased          400
# dtype: int64

# %%
df['EstimatedSalary'][:20]
# Out:
# 0      19000
# 1      20000
# 2      43000
# 3      57000
# 4      76000
# 5      58000
# 6      84000
# 7     150000
# 8      33000
# 9      65000
# 10     80000
# 11     52000
# 12     86000
# 13     18000
# 14     82000
# 15     80000
# 16     25000
# 17     26000
# 18     28000
# 19     29000
# Name: EstimatedSalary, dtype: int64

# %%
df.EstimatedSalary[:5]
# Out:
# 0    19000
# 1    20000
# 2    43000
# 3    57000
# 4    76000
# Name: EstimatedSalary, dtype: int64

# %%
df_age =df.groupby(['Gender'])

# %%
df[['Gender','Age','Purchased']]
# Out:
#      Gender  Age  Purchased
# 0      Male   19          0
# 1      Male   35          0
# 2    Female   26          0
# 3    Female   27          0
# 4      Male   19          0
# ..      ...  ...        ...
# 395  Female   46          1
# 396    Male   51          1
# 397  Female   50          1
# 398    Male   36          0
# 399  Female   49          1
#
# [400 rows x 3 columns]

# %%
df[10:25]
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 10  15570769  Female   26            80000          0
# 11  15606274  Female   26            52000          0
# 12  15746139    Male   20            86000          0
# 13  15704987    Male   32            18000          0
# 14  15628972    Male   18            82000          0
# 15  15697686    Male   29            80000          0
# 16  15733883    Male   47            25000          1
# 17  15617482    Male   45            26000          1
# 18  15704583    Male   46            28000          1
# 19  15621083  Female   48            29000          1
# 20  15649487    Male   45            22000          1
# 21  15736760  Female   47            49000          1
# 22  15714658    Male   48            41000          1
# 23  15599081  Female   45            22000          1
# 24  15705113    Male   46            23000          1

# %%
df[:2]
# Out:
#     User ID Gender  Age  EstimatedSalary  Purchased
# 0  15624510   Male   19            19000          0
# 1  15810944   Male   35            20000          0

# %%
df[:10]
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
df[::5]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 5    15728773    Male   27            58000          0
# 10   15570769  Female   26            80000          0
# 15   15697686    Male   29            80000          0
# 20   15649487    Male   45            22000          1
# ..        ...     ...  ...              ...        ...
# 375  15646091  Female   46            32000          1
# 380  15683758    Male   42            64000          0
# 385  15775335    Male   56            60000          1
# 390  15807837    Male   48            33000          1
# 395  15691863  Female   46            41000          1
#
# [80 rows x 5 columns]

# %%
df[::10]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 10   15570769  Female   26            80000          0
# 20   15649487    Male   45            22000          1
# 30   15581198    Male   31            74000          0
# 40   15764419  Female   27            17000          0
# 50   15694395  Female   24            32000          0
# 60   15814004    Male   27            20000          0
# 70   15756932    Male   25            80000          0
# 80   15595917    Male   30            80000          0
# 90   15684801    Male   22            81000          0
# 100  15766289    Male   27            88000          0
# 110  15665416  Female   39            71000          0
# 120  15811613  Female   36            75000          0
# 130  15675185    Male   31            58000          0
# 140  15807909    Male   19            85000          0
# 150  15679651  Female   26            15000          0
# ...

# %%
df[10::]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 10   15570769  Female   26            80000          0
# 11   15606274  Female   26            52000          0
# 12   15746139    Male   20            86000          0
# 13   15704987    Male   32            18000          0
# 14   15628972    Male   18            82000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [390 rows x 5 columns]

# %%
df[::100]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 100  15766289    Male   27            88000          0
# 200  15628523    Male   35            39000          0
# 300  15736397  Female   58            38000          1

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
#Calcualte for SD for all numeric values
df.EstimatedSalary.describe()
# Out:
# count       400.000000
# mean      69742.500000
# std       34096.960282
# min       15000.000000
# 25%       43000.000000
# 50%       70000.000000
# 75%       88000.000000
# max      150000.000000
# Name: EstimatedSalary, dtype: float64

# %%
df.EstimatedSalary.mean()
# Out:
# 69742.5

# %%
df.EstimatedSalary.std()
# Out:
# 34096.960282424785

# %%
df.EstimatedSalary.mode()
# Out:
# 0    72000
# Name: EstimatedSalary, dtype: int64

# %%
df.EstimatedSalary.count()
# Out:
# 400

# %%
df_Age = df.groupby(['EstimatedSalary'])

# %%
df_Age.head()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 392  15748589  Female   45            45000          1
# 393  15635893    Male   60            42000          1
# 395  15691863  Female   46            41000          1
# 397  15654296  Female   50            20000          1
# 399  15594041  Female   49            36000          1
#
# [350 rows x 5 columns]

# %%
df_Age

# %%
df.groupby(['Gender'], sort='False')[['Age']].mean()
# Out:
#               Age
# Gender
# Female  38.411765
# Male    36.867347

# %%
df_sub = df[df['Age']>20]

# %%
df_Age =df[df["Gender"] =="Male"]

# %%
df_Age
# Out:
#       User ID Gender  Age  EstimatedSalary  Purchased
# 0    15624510   Male   19            19000          0
# 1    15810944   Male   35            20000          0
# 4    15804002   Male   19            76000          0
# 5    15728773   Male   27            58000          0
# 8    15600575   Male   25            33000          0
# ..        ...    ...  ...              ...        ...
# 390  15807837   Male   48            33000          1
# 391  15592570   Male   47            23000          1
# 393  15635893   Male   60            42000          1
# 396  15706071   Male   51            23000          1
# 398  15755018   Male   36            33000          0
#
# [196 rows x 5 columns]

# %%
df_Age =df[df["Gender"] =="Female"]

# %%
df_Age
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 6    15598044  Female   27            84000          0
# 7    15694829  Female   32           150000          1
# 9    15727311  Female   35            65000          0
# ..        ...     ...  ...              ...        ...
# 392  15748589  Female   45            45000          1
# 394  15757632  Female   39            59000          0
# 395  15691863  Female   46            41000          1
# 397  15654296  Female   50            20000          1
# 399  15594041  Female   49            36000          1
#
# [204 rows x 5 columns]

# %%
df['Age']
# Out:
# 0      19
# 1      35
# 2      26
# 3      27
# 4      19
#        ..
# 395    46
# 396    51
# 397    50
# 398    36
# 399    49
# Name: Age, Length: 400, dtype: int64

# %%
df[['Age','Gender']]
# Out:
#      Age  Gender
# 0     19    Male
# 1     35    Male
# 2     26  Female
# 3     27  Female
# 4     19    Male
# ..   ...     ...
# 395   46  Female
# 396   51    Male
# 397   50  Female
# 398   36    Male
# 399   49  Female
#
# [400 rows x 2 columns]

# %%
#select rows for labels
df_sub.loc[10:20,['Age','Gender']]
# Out:
#     Age  Gender
# 10   26  Female
# 11   26  Female
# 13   32    Male
# 15   29    Male
# 16   47    Male
# 17   45    Male
# 18   46    Male
# 19   48  Female
# 20   45    Male

# %%
df_sorted = df.sort_values(by=['Age','Gender'],ascending =[True,False])

# %%
df_sorted
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 14   15628972    Male   18            82000          0
# 76   15746737    Male   18            52000          0
# 51   15764195  Female   18            44000          0
# 141  15666141  Female   18            68000          0
# 165  15578738  Female   18            86000          0
# ..        ...     ...  ...              ...        ...
# 355  15606472    Male   60            34000          1
# 371  15774744    Male   60            83000          1
# 393  15635893    Male   60            42000          1
# 215  15779529  Female   60           108000          1
# 370  15611430  Female   60            46000          1
#
# [400 rows x 5 columns]

# %%
df_sorted.head(100)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 14   15628972    Male   18            82000          0
# 76   15746737    Male   18            52000          0
# 51   15764195  Female   18            44000          0
# 141  15666141  Female   18            68000          0
# 165  15578738  Female   18            86000          0
# ..        ...     ...  ...              ...        ...
# 192  15779581    Male   29            43000          0
# 52   15744919  Female   29            83000          0
# 93   15699284  Female   29            28000          0
# 94   15786993  Female   29            83000          0
# 169  15579781  Female   29            47000          0
#
# [100 rows x 5 columns]

# %%
df[['Age','EstimatedSalary']].agg(['min','mean','max'])
# Out:
#          Age  EstimatedSalary
# min   18.000          15000.0
# mean  37.655          69742.5
# max   60.000         150000.0

# %%
# %matplotlib inline

# %%
#plot using histogram
plt.hist(df['Age'],bins=8, density=1)
# Out:
# (array([0.01619048, 0.02666667, 0.02380952, 0.03952381, 0.03190476,
#         0.02714286, 0.01047619, 0.0147619 ]),
#  array([18.  , 23.25, 28.5 , 33.75, 39.  , 44.25, 49.5 , 54.75, 60.  ]),
#  <BarContainer object of 8 artists>)

# %%
sns.distplot(df[('Age')])
# Out:
# C:\Windows\Temp\ipykernel_10956\1418142353.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[('Age')])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#display Matplotlib using bar
df.groupby(['Gender'])['Age'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
#split the Groups
sns.set_style('whitegrid')

# %%
ax = sns.barplot(x="Gender", y="Age",hue="Gender", data=df,estimator=len)

# %%
#scaterplot in seaborn
sns.jointplot(x="Gender", y="Age", data=df)

# %%
#box plot
sns.boxplot(x="Gender", y="Age", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.scatterplot(x="Gender", y="Age", data=df,hue='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>
