# %% [markdown]
# # Step 1: Import the necessary packages

# %%
# importing modules and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing

# %% [markdown]
# # Step 2: Import the CSV file:

# %%
# importing data
df = pd.read_csv("C:/Users/getne/Desktop/MSC/Data Science/Real-estate1.csv")
df.drop('No', inplace = True,axis=1)

print(df.head())
print(df.columns)
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %% [markdown]
# # Step 3: Create a scatterplot to visualize the data:

# %%
# plotting a scatterplot
sns.scatterplot(x='X4 number of convenience stores',
				y='Y house price of unit area', data=df)
# Out:
# <Axes: xlabel='X4 number of convenience stores', ylabel='Y house price of unit area'>

# %% [markdown]
# # Step 4: Create feature variables:

# %%
# creating feature variables
X = df.drop('Y house price of unit area',axis= 1)
y = df['Y house price of unit area']
X.head()
#print(y)
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245

# %% [markdown]
# # Step 5: Split data into train and test sets:

# %%
# creating train and test sets
X_train, X_test, y_train, y_test = train_test_split(	X, y, test_size=0.3, random_state=101)

# %% [markdown]
#  # Step 6: Create a linear regression model

# %%
# creating a regression model
model = LinearRegression()

# %% [markdown]
# # Step 7: Fit the model with training data.

# %%
# fitting the model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Step 8: Make predictions on the test data set.

# %%
# making predictions
predictions = model.predict(X_test)

# %% [markdown]
# # Step 9: Evaluate the model with metrics.

# %%
# model evaluation
print(
'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  46.21179783493614
# mean_absolute_error :  5.392293684756542

# %% [markdown]
# # Pie Plot in python

# %%
# import Modules
import numpy as pp 
import matplotlib.pyplot as plt # used for plotting
#%matplotlib widget
#define y_data
y= np.array([4,72,100])
#add lable to the y values
my_label = ['Data Science', 'Database','Stat']
#plot pie, plot with labels
#give explode parameters
explode =[0.1,0.1,0.1] # it will separate with each other
plt.pie(y, labels =my_label, explode=explode,startangle=45, autopct='%1.2f%%', shadow=True)

#add, title, x,y labels, control font size
plt.title('MSC Courses First Semister', color='Green', fontsize=20)
plt.show()

# %% [markdown]
# # Bar graph using python
